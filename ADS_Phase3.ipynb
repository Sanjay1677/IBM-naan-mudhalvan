# %% [markdown]
# # ELECTRICITY PRICE PREDICTION

# %% [markdown]
# ## IMPORT THE NECESSARY PACKAGES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ## LOAD THE DATASET

# %%
data = pd.read_csv("Electricity.csv")
# Out:
# C:\Users\SANJAY\AppData\Local\Temp\ipykernel_5072\1267927612.py:2: DtypeWarning: Columns (9,10,11,14,15,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Electricity.csv")

# %% [markdown]
# ## EXPLORE THE DATASET

# %%
data.head()
# Out:
#            DateTime Holiday  HolidayFlag  DayOfWeek  WeekOfYear  Day  Month  \
# 0  01/11/2011 00:00     NaN            0          1          44    1     11
# 1  01/11/2011 00:30     NaN            0          1          44    1     11
# 2  01/11/2011 01:00     NaN            0          1          44    1     11
# 3  01/11/2011 01:30     NaN            0          1          44    1     11
# 4  01/11/2011 02:00     NaN            0          1          44    1     11
#
#    Year  PeriodOfDay ForecastWindProduction SystemLoadEA  SMPEA  \
# 0  2011            0                 315.31      3388.77  49.26
# 1  2011            1                 321.80      3196.66  49.26
# 2  2011            2                 328.57      3060.71  49.10
# 3  2011            3                 335.60      2945.56  48.04
# 4  2011            4                 342.90      2849.34  33.75
#
#   ORKTemperature ORKWindspeed CO2Intensity ActualWindProduction SystemLoadEP2  \
# 0           6.00         9.30       600.71               356.00       3159.60
# 1           6.00        11.10       605.42               317.00       2973.01
# 2           5.00        11.10       589.97               311.00       2834.00
# 3           6.00         9.30       585.94               313.00       2725.99
# 4           6.00        11.10       571.52               346.00       2655.64
#
#   SMPEP2
# 0  54.32
# 1  54.23
# 2  54.23
# 3  53.47
# 4  39.87

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38014 entries, 0 to 38013
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DateTime                38014 non-null  object
#  1   Holiday                 35470 non-null  object
#  2   HolidayFlag             38014 non-null  int64
#  3   DayOfWeek               38014 non-null  int64
#  4   WeekOfYear              38014 non-null  int64
#  5   Day                     38014 non-null  int64
#  6   Month                   38014 non-null  int64
#  7   Year                    38014 non-null  int64
#  8   PeriodOfDay             38014 non-null  int64
#  9   ForecastWindProduction  38014 non-null  object
#  10  SystemLoadEA            38014 non-null  object
#  11  SMPEA                   38014 non-null  object
#  12  ORKTemperature          38014 non-null  object
#  13  ORKWindspeed            38014 non-null  object
#  14  CO2Intensity            38014 non-null  object
#  15  ActualWindProduction    38014 non-null  object
#  16  SystemLoadEP2           38014 non-null  object
#  17  SMPEP2                  38014 non-null  object
# dtypes: int64(7), object(11)
# memory usage: 5.2+ MB

# %%
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38014 entries, 0 to 38013
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DateTime                38014 non-null  object
#  1   Holiday                 1536 non-null   object
#  2   HolidayFlag             38014 non-null  int64
#  3   DayOfWeek               38014 non-null  int64
#  4   WeekOfYear              38014 non-null  int64
#  5   Day                     38014 non-null  int64
#  6   Month                   38014 non-null  int64
#  7   Year                    38014 non-null  int64
#  8   PeriodOfDay             38014 non-null  int64
#  9   ForecastWindProduction  38014 non-null  object
#  10  SystemLoadEA            38014 non-null  object
#  11  SMPEA                   38014 non-null  object
#  12  ORKTemperature          38014 non-null  object
#  13  ORKWindspeed            38014 non-null  object
#  14  CO2Intensity            38014 non-null  object
#  15  ActualWindProduction    38014 non-null  object
#  16  SystemLoadEP2           38014 non-null  object
#  17  SMPEP2                  38014 non-null  object
# dtypes: int64(7), object(11)
# memory usage: 5.2+ MB
#         HolidayFlag     DayOfWeek    WeekOfYear           Day         Month  \
# count  38014.000000  38014.000000  38014.000000  38014.000000  38014.000000
# mean       0.040406      2.997317     28.124586     15.739412      6.904246
# std        0.196912      1.999959     15.587575      8.804247      3.573696
# min        0.000000      0.000000      1.000000      1.000000      1.000000
# 25%        0.000000      1.000000     15.000000      8.000000      4.000000
# 50%        0.000000      3.000000     29.000000     16.000000      7.000000
# 75%        0.000000      5.000000     43.000000     23.000000     10.000000
# max        1.000000      6.000000     52.000000     31.000000     12.000000
#
#                Year   PeriodOfDay
# count  38014.000000  38014.000000
# mean    2012.383859     23.501105
# std        0.624956     13.853108
# min     2011.000000      0.000000
# 25%     2012.000000     12.000000
# 50%     2012.000000     24.000000
# 75%     2013.000000     35.750000
# max     2013.000000     47.000000

# %%
data.shape
# Out:
# (38014, 18)

# %%
data.isnull().sum()
# Out:
# DateTime                     0
# Holiday                   2544
# HolidayFlag                  0
# DayOfWeek                    0
# WeekOfYear                   0
# Day                          0
# Month                        0
# Year                         0
# PeriodOfDay                  0
# ForecastWindProduction       0
# SystemLoadEA                 0
# SMPEA                        0
# ORKTemperature               0
# ORKWindspeed                 0
# CO2Intensity                 0
# ActualWindProduction         0
# SystemLoadEP2                0
# SMPEP2                       0
# dtype: int64

# %% [markdown]
# ## DATA PRE-PROCESSING

# %%
data_cleaned =data.dropna()

data_cleaned.info()

data_cleaned.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35470 entries, 2544 to 38013
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DateTime                35470 non-null  object
#  1   Holiday                 35470 non-null  object
#  2   HolidayFlag             35470 non-null  int64
#  3   DayOfWeek               35470 non-null  int64
#  4   WeekOfYear              35470 non-null  int64
#  5   Day                     35470 non-null  int64
#  6   Month                   35470 non-null  int64
#  7   Year                    35470 non-null  int64
#  8   PeriodOfDay             35470 non-null  int64
#  9   ForecastWindProduction  35470 non-null  object
#  10  SystemLoadEA            35470 non-null  object
#  11  SMPEA                   35470 non-null  object
#  12  ORKTemperature          35470 non-null  object
#  13  ORKWindspeed            35470 non-null  object
#  14  CO2Intensity            35470 non-null  object
#  15  ActualWindProduction    35470 non-null  object
#  16  SystemLoadEP2           35470 non-null  object
#  17  SMPEP2                  35470 non-null  object
# dtypes: int64(7), object(11)
# memory usage: 5.1+ MB
#         HolidayFlag     DayOfWeek    WeekOfYear           Day         Month  \
# count  35470.000000  35470.000000  35470.000000  35470.000000  35470.000000
# mean       0.043304      2.999831     26.739667     15.865520      6.579363
# std        0.203544      2.003338     15.211544      8.843639      3.477424
# min        0.000000      0.000000      1.000000      1.000000      1.000000
# 25%        0.000000      1.000000     14.000000      8.000000      4.000000
# 50%        0.000000      3.000000     27.000000     16.000000      7.000000
# 75%        0.000000      5.000000     40.000000     24.000000     10.000000
# max        1.000000      6.000000     52.000000     31.000000     12.000000
#
#                Year   PeriodOfDay
# count  35470.000000  35470.000000
# mean    2012.483112     23.501184
# std        0.520936     13.853087
# min     2011.000000      0.000000
# 25%     2012.000000     12.000000
# 50%     2012.000000     24.000000
# 75%     2013.000000     35.750000
# max     2013.000000     47.000000

# %% [markdown]
# ### DATA CLEANING

# %%
data_new =data_cleaned.drop(['SystemLoadEA'],axis = 1)
data_new.head()
# Out:
#               DateTime        Holiday  HolidayFlag  DayOfWeek  WeekOfYear  \
# 2544  24/12/2011 00:00  Christmas Eve            1          5          51
# 2545  24/12/2011 00:30  Christmas Eve            1          5          51
# 2546  24/12/2011 01:00  Christmas Eve            1          5          51
# 2547  24/12/2011 01:30  Christmas Eve            1          5          51
# 2548  24/12/2011 02:00  Christmas Eve            1          5          51
#
#       Day  Month  Year  PeriodOfDay ForecastWindProduction  SMPEA  \
# 2544   24     12  2011            0                 718.70  44.96
# 2545   24     12  2011            1                 741.10  44.54
# 2546   24     12  2011            2                 768.00  42.73
# 2547   24     12  2011            3                 806.90  41.72
# 2548   24     12  2011            4                 845.90  41.56
#
#      ORKTemperature ORKWindspeed CO2Intensity ActualWindProduction  \
# 2544           2.00        11.10       477.20               666.00
# 2545           3.00        18.50       467.15               641.00
# 2546           3.00        16.70       469.53               644.00
# 2547           4.00        14.80       467.95               645.00
# 2548           3.00        11.10       470.66               693.00
#
#      SystemLoadEP2 SMPEP2
# 2544       3634.24  44.96
# 2545       3382.16  44.96
# 2546       3204.06  44.54
# 2547       2997.83  43.48
# 2548       2831.80  41.72

# %%
data_new.reset_index(drop=True, inplace=True)

# %% [markdown]
# #### AFTER PRE-PROCESSING THE DATA WILL BE LIKE THIS

# %%
data_new.head()
# Out:
#            DateTime        Holiday  HolidayFlag  DayOfWeek  WeekOfYear  Day  \
# 0  24/12/2011 00:00  Christmas Eve            1          5          51   24
# 1  24/12/2011 00:30  Christmas Eve            1          5          51   24
# 2  24/12/2011 01:00  Christmas Eve            1          5          51   24
# 3  24/12/2011 01:30  Christmas Eve            1          5          51   24
# 4  24/12/2011 02:00  Christmas Eve            1          5          51   24
#
#    Month  Year  PeriodOfDay ForecastWindProduction  SMPEA ORKTemperature  \
# 0     12  2011            0                 718.70  44.96           2.00
# 1     12  2011            1                 741.10  44.54           3.00
# 2     12  2011            2                 768.00  42.73           3.00
# 3     12  2011            3                 806.90  41.72           4.00
# 4     12  2011            4                 845.90  41.56           3.00
#
#   ORKWindspeed CO2Intensity ActualWindProduction SystemLoadEP2 SMPEP2
# 0        11.10       477.20               666.00       3634.24  44.96
# 1        18.50       467.15               641.00       3382.16  44.96
# 2        16.70       469.53               644.00       3204.06  44.54
# 3        14.80       467.95               645.00       2997.83  43.48
# 4        11.10       470.66               693.00       2831.80  41.72
